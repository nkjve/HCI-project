# %% [markdown]
# <a href="https://colab.research.google.com/github/nkjve/HCI-project/blob/main/HCI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import functions

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Train DS

# %%
train = pd.read_csv("/content/drive/MyDrive/train.csv")
train
# Out:
#              Var1         Var2   Var3          Var4 Var5
# 0              is     chairman     of          N.V.    N
# 1           named     director     of  conglomerate    N
# 2          caused   percentage     of        deaths    N
# 3           using  crocidolite     in       filters    V
# 4           bring    attention     to       problem    V
# ...           ...          ...    ...           ...  ...
# 3091      testing  stimulators     in   conjunction    V
# 3092      prevent      wasting     of       muscles    N
# 3093  reorganizes    resources  after    amputation    V
# 3094    exploring   perception   with      machines    V
# 3095        flash       groups     of       letters    N
#
# [3096 rows x 5 columns]

# %% [markdown]
# Test DS

# %%
test = pd.read_csv("/content/drive/MyDrive/test.csv")
test
# Out:
#            Verb           Noun    Prep  Prep_obj Class_label
# 0       shipped          crabs    from  province           V
# 1           ran      broadcast      on       way           N
# 2            is      apartment    with    floors           N
# 3       tending         meters  during     shift           V
# 4           are      prospects     for  mobility           N
# ...         ...            ...     ...       ...         ...
# 1995   offering        rebates      on  vehicles           V
# 1996  highlight  vulnerability      of     maker           N
# 1997      boost          sales  during   quarter           V
# 1998        cut     production  during   quarter           V
# 1999     pushed     operations      of      each           N
#
# [2000 rows x 5 columns]

# %%
train= train.rename(columns={"Var5":"Class_label"})
train
# Out:
#              Var1         Var2   Var3          Var4 Class_label
# 0              is     chairman     of          N.V.           N
# 1           named     director     of  conglomerate           N
# 2          caused   percentage     of        deaths           N
# 3           using  crocidolite     in       filters           V
# 4           bring    attention     to       problem           V
# ...           ...          ...    ...           ...         ...
# 3091      testing  stimulators     in   conjunction           V
# 3092      prevent      wasting     of       muscles           N
# 3093  reorganizes    resources  after    amputation           V
# 3094    exploring   perception   with      machines           V
# 3095        flash       groups     of       letters           N
#
# [3096 rows x 5 columns]
